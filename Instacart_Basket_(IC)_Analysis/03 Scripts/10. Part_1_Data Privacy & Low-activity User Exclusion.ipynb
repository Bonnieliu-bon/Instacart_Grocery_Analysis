# %% [markdown]
# # 10. Part 1_Data Privacy & Low-activity User Exclusion
# ## Table of Contents
# ***
#
# **`1. Import libraries`**
#
# **`2. Create path and import data`**
#
# **`3. Create an user exclusion for low-activity customers`**
#
# **`4. Export user exclusion data`**
#
# ***

# %% [markdown]
# ### 1. Import libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns
import scipy
import os

# %% [markdown]
# ### 2. Create path and import data

# %%
# Create path
path= r'/Users/bonnieandbanana/Desktop/A New Career/CareerFoundry/Data Immersion/A4_Python/ Instacart Basket Analysis Project (IC)'

# Import data
df = pd.read_pickle(os.path.join(path,'02 data' , 'prepared data', 'new_orders_products_customers_merged.pkl'))

# %%
pd.options.display.max_columns = None

# %%
df['age'] = pd.to_numeric(df['age'])

# %%
df.head(5)
# Out:
#    order_id user_id  order_number  order_day_of_the_week  order_hour_of_day  \
# 0   2539329       1             1                      2                  8
# 1   2398795       1             2                      3                  7
# 2    473747       1             3                      3                 12
# 3   2254736       1             4                      4                  7
# 4    431534       1             5                      4                 15
#
#    days_since_last_order  first_order  product_id  add_to_cart_order  \
# 0                    NaN         True         196                  1
# 1                   15.0        False         196                  1
# 2                   21.0        False         196                  1
# 3                   29.0        False         196                  1
# 4                   28.0        False         196                  1
#
#    reordered product_name  aisle_id  department_id  prices    price_range_loc  \
# ...

# %% [markdown]
# **Identifying personally identifiable information (PII):** <br/>
# Colmuns of 'first_name', 'surname' are identified as PII.

# %% [markdown]
# ###  3. Create an exclusion flag: low-activity & high-activity customers

# %%
# Create a flag for customers with less than 5 orders
df.loc[ df ['max_order'] <5 , 'activity_flag'] = 'low-activity customer'
df.loc[ df['max_order'] >= 5, 'activity_flag'] = 'high-activity customer'

# %%
# Check value counts
df['activity_flag'].value_counts(dropna = False)
# Out:
# high-activity customer    30959687
# Name: activity_flag, dtype: int64

# %%
# Exclude the low-activity customers from the dataframe
df = df[df['activity_flag'] == 'high-activity customer']

# %%
# Check shape
df.shape
# Out:
# (30959687, 39)

# %% [markdown]
# **Confirmed that the number of rows match with the rows of high-activity customer**

# %% [markdown]
# ### 4. Export user exclusion data

# %%
# Export the exclusion as pickle
df.to_pickle(os.path.join(path, '02 data' , 'prepared data' , 'low-activity_cus_excluded.pkl'))
